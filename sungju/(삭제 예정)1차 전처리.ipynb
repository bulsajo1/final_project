# %%
import pandas as pd
import glob
import os

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202301_성남시.csv"

# 파일 존재 여부 먼저 확인
print(os.path.exists(file_path))

# True가 나오면 실행
df = pd.read_csv(file_path, nrows=5, encoding="utf-8-sig")

df
# Out:
# True
#    ETL_YM DOW  D_TIME_CD  D_CTY_CD D_MEGA_NM D_CTY_NM  D_CENTER_X  D_CENTER_Y  \
# 0  202301   월         21     41135       경기도  성남시 분당구      965120     1931210
# 1  202301   일         13     41133       경기도  성남시 중원구      970268     1937199
# 2  202301   화         14     41133       경기도  성남시 중원구      970268     1937199
# 3  202301   수         22     41131       경기도  성남시 수정구      964981     1937423
# 4  202301   토         20     41135       경기도  성남시 분당구      965120     1931210
#
#    TRANS_GB SEX_CD  AGE_GRP      CNT
# 0         1      W        2  1459.27
# 1         0      M        6  3192.18
# 2         7      M        9    43.18
# 3         0      W        6  1477.35
# 4         3      W        1   229.50

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202301_성남시.csv"

# 파일 존재 여부 먼저 확인
print(os.path.exists(file_path))

# True가 나오면 실행
df_2 = pd.read_csv(file_path, nrows=5, encoding="utf-8-sig")

df_2
# Out:
# True
#     ETL_YMD  D_TIME_CD  D_ADMI_CD D_MEGA_NM D_CTY_NM D_ADMI_NM  D_CENTER_X  \
# 0  20230124         19   41135650       경기도  성남시 분당구       판교동      963992
# 1  20230115         10   41133660       경기도  성남시 중원구      하대원동      968696
# 2  20230108          9   41133510       경기도  성남시 중원구       성남동      967502
# 3  20230125         16   41133560       경기도  성남시 중원구      은행2동      971264
# 4  20230127         10   41135560       경기도  성남시 분당구      정자2동      966201
#
#    D_CENTER_Y  TRANS_GB SEX_CD  AGE_GRP    CNT
# 0     1932720         7      M        5  17.14
# 1     1936625         1      M        2   3.38
# 2     1936961         2      M        2   8.64
# 3     1940268         7      M        4   3.37
# 4     1929810         7      M        6   5.08

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202310_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_통합.csv"

# %%
if os.path.exists(output_file):
    os.remove(output_file)
first = True

# %%
for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202309_성남시.csv
# ...

# %%
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

# %%
pip install fastparquet
# Out:
# ...
#    ---------------------------------------- 0.0/667.9 kB ? eta -:--:--
#    ------------------------------- -------- 524.3/667.9 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 667.9/667.9 kB 3.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ------------- -------------------------- 1/3 [cramjam]
#    -------------------------- ------------- 2/3 [fastparquet]
#    -------------------------- ------------- 2/3 [fastparquet]
# ...

# %%
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\2024_통합.csv"

# %%
if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202409_성남시.csv
# ...

# %%
df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202510_성남시.csv
# ...

# %%
for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\T11_GG_TRANS_SEXAGE_ADMI_OUTFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2025\2025_확인.parquet")

# %%
# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# %%
# parquet 저장
df_all.to_parquet("t11_all.parquet", index=False)

# %% [markdown]
# ## t5

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202310_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

# %%
for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202309_성남시.csv
# ...

# %%
# 파일 경로
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\2023_통합.csv"

# 컬럼명만 확인 (전체 파일 다 안 읽고 빠르게)
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

df.columns.tolist()
# Out:
# ['ETL_YMD',
#  'D_TIME_CD',
#  'D_ADMI_CD',
#  'D_MEGA_NM',
#  'D_CTY_NM',
#  'D_ADMI_NM',
#  'D_CENTER_X',
#  'D_CENTER_Y',
#  'PURPOSE',
#  'SEX_CD',
#  'AGE_GRP',
#  'CNT']

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

# %%
for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202409_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

# %%
for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\T5_GG_PURPOSE_SEXAGE_ADMI_INFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T5\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t5_all.parquet", index=False)

# %% [markdown]
# ## t7

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202310_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202309_성남시.csv
# ...

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\2023_통합.csv"

# 컬럼명만 확인 (전체 파일 다 안 읽고 빠르게)
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

df.columns.tolist()
# Out:
# ['ETL_YMD',
#  'D_TIME_CD',
#  'D_ADMI_CD',
#  'D_MEGA_NM',
#  'D_CTY_NM',
#  'D_ADMI_NM',
#  'D_CENTER_X',
#  'D_CENTER_Y',
#  'TRANS_GB',
#  'SEX_CD',
#  'AGE_GRP',
#  'CNT']

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202301_성남시.csv"

# 컬럼명 확인
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

print(df.columns.tolist())
# Out:
# ['ETL_YMD', 'D_TIME_CD', 'D_ADMI_CD', 'D_MEGA_NM', 'D_CTY_NM', 'D_ADMI_NM', 'D_CENTER_X', 'D_CENTER_Y', 'TRANS_GB', 'SEX_CD', 'AGE_GRP', 'CNT']

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202409_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\*.csv"
    )
)

# %%
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t7_all.parquet", index=False)

# %% [markdown]
# ## t4

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202310_성남시.csv
# ...

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202301_성남시.csv"

# 컬럼명 확인
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

print(df.columns.tolist())
# Out:
# ['ETL_YM', 'DOW', 'D_TIME_CD', 'D_CTY_CD', 'D_MEGA_NM', 'D_CTY_NM', 'D_CENTER_X', 'D_CENTER_Y', 'PURPOSE', 'SEX_CD', 'AGE_GRP', 'CNT']

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202309_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202409_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\T4_GG_PURPOSE_SEXAGE_SGG_INFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T4\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t4_all.parquet", index=False)

# %% [markdown]
# ## t6

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\*.csv"
    )
)
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202310_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202309_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202310_성남시.csv
# ...

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202301_성남시.csv"

# 파일 존재 여부 먼저 확인
print(os.path.exists(file_path))

# True가 나오면 실행
df = pd.read_csv(file_path, nrows=5, encoding="utf-8-sig")

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202301_성남시.csv"
#       3 # 파일 존재 여부 먼저 확인
# ----> 4 print(os.path.exists(file_path))
#       6 # True가 나오면 실행
#       7 df = pd.read_csv(file_path, nrows=5, encoding="utf-8-sig")
#
# NameError: name 'os' is not defined

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202309_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202310_성남시.csv
# ...

# %%
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# ## 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\*.csv"
    )
)
print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202409_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202410_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202509_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\T6_GG_TRANS_SEXAGE_SGG_INFLOW_202510_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T6\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t6_all.parquet", index=False)

# %% [markdown]
# # t8

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202310_성남시.csv
# ...

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202301_성남시.csv"

# 컬럼명 확인
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

print(df.columns.tolist())
# Out:
# ['ETL_YM', 'DOW', 'O_TIME_CD', 'O_CTY_CD', 'O_MEGA_NM', 'O_CTY_NM', 'O_CENTER_X', 'O_CENTER_Y', 'PURPOSE', 'SEX_CD', 'AGE_GRP', 'CNT']

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202309_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202409_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\T8_GG_PURPOSE_SEXAGE_SGG_OUTFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T8\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t8_all.parquet", index=False)

# %% [markdown]
# # t9

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202310_성남시.csv
# ...

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202301_성남시.csv"

# 컬럼명 확인
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

df.columns.tolist()
# Out:
# ['ETL_YMD',
#  'O_TIME_CD',
#  'O_ADMI_CD',
#  'O_MEGA_NM',
#  'O_CTY_NM',
#  'O_ADMI_NM',
#  'O_CENTER_X',
#  'O_CENTER_Y',
#  'PURPOSE',
#  'SEX_CD',
#  'AGE_GRP',
#  'CNT']

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202309_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202409_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\T9_GG_PURPOSE_SEXAGE_ADMI_OUTFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T9\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t9_all.parquet", index=False)

# %% [markdown]
# # t10

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202301_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202302_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202303_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202304_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202305_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202306_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202307_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202308_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202309_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202310_성남시.csv
# ...

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202301_성남시.csv"

# 컬럼명 확인
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

df.columns.tolist()
# Out:
# ['ETL_YM',
#  'DOW',
#  'O_TIME_CD',
#  'O_CTY_CD',
#  'O_MEGA_NM',
#  'O_CTY_NM',
#  'O_CENTER_X',
#  'O_CENTER_Y',
#  'TRANS_GB',
#  'SEX_CD',
#  'AGE_GRP',
#  'CNT']

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202301_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202302_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202303_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202304_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202305_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202306_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202307_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202308_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202309_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2024

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202401_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202402_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202403_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202404_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202405_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202406_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202407_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202408_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202409_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202410_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\2024_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2024 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202401_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202402_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202403_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202404_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202405_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202406_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202407_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202408_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202409_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\2024_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\2024_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %% [markdown]
# # 2025

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)
# Out:
# 파일 개수: 12
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202501_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202502_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202503_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202504_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202505_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202506_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202507_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202508_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202509_성남시.csv
# C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202510_성남시.csv
# ...

# %%
# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\2025_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2025 통합 완료")
# Out:
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202501_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202502_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202503_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202504_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202505_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202506_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202507_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202508_성남시.csv
# 처리 중: C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\T10_GG_TRANS_SEXAGE_SGG_OUTFLOW_202509_성남시.csv
# ...

# %%
# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\2025_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\2025_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")
# Out:
# ✅ parquet 저장 완료

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T10\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t10_all.parquet", index=False)

# %%
files = sorted(
    glob.glob(
        r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\*.csv"
    )
)

print("파일 개수:", len(files))
for f in files:
    print(f)


# 코드이름 바꿔서 저장
output_file = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_통합.csv"

if os.path.exists(output_file):
    os.remove(output_file)
first = True

for file in files:
    print(f"처리 중: {file}")

    for chunk in pd.read_csv(file, chunksize=100000, encoding="utf-8-sig"):
        chunk.columns = chunk.columns.str.strip()

        if first:
            chunk.to_csv(output_file, index=False, mode="w", encoding="utf-8-sig")
            first = False
        else:
            chunk.to_csv(output_file, index=False, mode="a", header=False, encoding="utf-8-sig")

print("✅ 2023 통합 완료")

# 파케이 변환
df = pd.read_csv(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_통합.csv",
    encoding="utf-8-sig"
)

df.to_parquet(
    r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T11\2023\2023_확인.parquet",
    index=False
)

print("✅ parquet 저장 완료")

# %%
file_path = r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\T7_GG_TRANS_SEXAGE_ADMI_INFLOW_202301_성남시.csv"

# 컬럼명 확인
df = pd.read_csv(file_path, nrows=5, encoding='utf-8-sig')

print(df.columns.tolist())

# %%
# parquet 불러오기
df_2023 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2023\2023_확인.parquet")
df_2024 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2024\2024_확인.parquet")
df_2025 = pd.read_parquet(r"C:\Users\cute3\OneDrive\Desktop\성남시\통신\T7\2025\2025_확인.parquet")

# 세로 통합
df_all = pd.concat(
    [df_2023, df_2024, df_2025],
    axis=0,
    ignore_index=True
)

# parquet 저장
df_all.to_parquet("t7_all.parquet", index=False)
