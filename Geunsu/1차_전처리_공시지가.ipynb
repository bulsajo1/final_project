# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\rmstn\final_project\Geunsu\data\성남시_공시지가_통합__202604241636.csv", encoding='cp949')
df
# Out:
#                       고유번호       법정동코드             법정동명 특수지구분명     지번  기준연도  \
# 0      4113511700100760002  4113511700  경기도 성남시 분당구 석운동     일반   76-2  2023
# 1      4113511700100780006  4113511700  경기도 성남시 분당구 석운동     일반   78-6  2023
# 2      4113511700100780007  4113511700  경기도 성남시 분당구 석운동     일반   78-7  2023
# 3      4113511700100780009  4113511700  경기도 성남시 분당구 석운동     일반   78-9  2023
# 4      4113511700100780010  4113511700  경기도 성남시 분당구 석운동     일반  78-10  2023
# ...                    ...         ...              ...    ...    ...   ...
# 15552  4113310300148000000  4113310300  경기도 성남시 중원구 금광동     일반   4800  2025
# 15553  4113310300148140000  4113310300  경기도 성남시 중원구 금광동     일반   4814  2025
# 15554  4113310300148160000  4113310300  경기도 성남시 중원구 금광동     일반   4816  2025
# 15555  4113310300148400000  4113310300  경기도 성남시 중원구 금광동     일반   4840  2025
# 15556  4113310300148460000  4113310300  경기도 성남시 중원구 금광동     일반   4846  2025
#
#        기준월     공시지가 표준지여부        기준년월 건물용도분류명
# ...

# %%
df.to_csv('전처리완료_부동산(공시지가).csv', index=False)
